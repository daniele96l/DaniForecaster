    all_unique_tickers.update(year_data)

full_ticker_list = list(all_unique_tickers)
print(f"Found {len(full_ticker_list)} unique tickers across all years in QQQ_List.")
# Out:
# Found 198 unique tickers across all years in QQQ_List.

# %%
import requests
import pandas as pd
import time
from datetime import date

# Marketstack API base URL
BASE_URL = 'https://api.marketstack.com/v1/'

start_date = '2003-12-29'
today = date.today().isoformat()
print(f"Fetching data from {start_date} to {today}")
# Out:
# Fetching data from 2003-12-29 to 2026-04-06

# %%
all_stock_data = []
# Paginate until a short page; do not use pagination.total (often capped at 1000 → one page only).
PAGE = 1000

for ticker in full_ticker_list:
    offset = 0
    while True:
        params = {
            'access_key': API_KEY_MARKETSTACK,
            'symbols': ticker,
            'date_from': start_date,
            'date_to': today,
            'limit': PAGE,
            'offset': offset,
        }

        try:
            response = requests.get(f"{BASE_URL}eod", params=params)
            response.raise_for_status()
            data = response.json()

            rows = (data or {}).get('data') or []
            if not rows:
                if offset == 0:
                    print(f"No data for {ticker}")
                break

            print(f"Fetched {len(rows)} rows for {ticker} (offset {offset})")

            for entry in rows:
                all_stock_data.append({
                    'Date': entry['date'].split('T')[0],
                    'Ticker': entry['symbol'],
                    'Open': entry['open'],
                    'High': entry['high'],
                    'Low': entry['low'],
                    'Close': entry['close'],
                    'Volume': entry['volume'],
                })

            if len(rows) < PAGE:
                break

            offset += len(rows)
            time.sleep(0.1)

        except Exception as e:
            print(f"Error for {ticker} at offset {offset}: {e}")
            break

# Create DataFrame
if all_stock_data:
    df_nasdaq_eod = pd.DataFrame(all_stock_data)
    df_nasdaq_eod['Date'] = pd.to_datetime(df_nasdaq_eod['Date'])
    df_nasdaq_eod = df_nasdaq_eod.sort_values(['Ticker', 'Date'])
    print(f"\nSuccessfully fetched {len(df_nasdaq_eod)} total rows across all tickers.")
else:
    df_nasdaq_eod = pd.DataFrame(columns=['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Volume'])
    print("No data was collected.")
# Out:
# Fetched 997 rows for WBD (Offset: 0)
# Fetched 479 rows for FER (Offset: 0)
# Fetched 1000 rows for INTU (Offset: 0)
# Fetched 1000 rows for KLAC (Offset: 0)
# Fetched 1000 rows for MNST (Offset: 0)
# Fetched 1000 rows for MRVL (Offset: 0)
# Error for CMCSK at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=CMCSK&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for ADP (Offset: 0)
# Fetched 1000 rows for SRCL (Offset: 0)
# Fetched 1000 rows for FANG (Offset: 0)
# Fetched 1000 rows for LBTYA (Offset: 0)
# Fetched 1000 rows for ORLY (Offset: 0)
# Fetched 1000 rows for AMAT (Offset: 0)
# Fetched 1000 rows for PTON (Offset: 0)
# Fetched 1000 rows for META (Offset: 0)
# Fetched 1000 rows for VRTX (Offset: 0)
# Fetched 1000 rows for LILA (Offset: 0)
# Fetched 640 rows for ARM (Offset: 0)
# Fetched 1000 rows for PANW (Offset: 0)
# Fetched 1000 rows for LULU (Offset: 0)
# Fetched 1000 rows for NXPI (Offset: 0)
# Fetched 1000 rows for WDAY (Offset: 0)
# Error for HANS at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=HANS&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for AEP (Offset: 0)
# Error for CTRP at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=CTRP&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Error for GMCR at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=GMCR&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 46 rows for VIP (Offset: 0)
# Fetched 1000 rows for XRAY (Offset: 0)
# Fetched 1000 rows for MDLZ (Offset: 0)
# Fetched 1000 rows for ABNB (Offset: 0)
# Fetched 1000 rows for ODFL (Offset: 0)
# Fetched 1000 rows for CCEP (Offset: 0)
# Fetched 1000 rows for AXON (Offset: 0)
# Fetched 1000 rows for AAPL (Offset: 0)
# Fetched 1000 rows for PCAR (Offset: 0)
# Fetched 1000 rows for SNPS (Offset: 0)
# Fetched 1000 rows for TSLA (Offset: 0)
# Fetched 1000 rows for MXIM (Offset: 0)
# Fetched 1000 rows for CSCO (Offset: 0)
# Fetched 1000 rows for MSTR (Offset: 0)
# Error for CEPH at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=CEPH&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for BKR (Offset: 0)
# Fetched 1000 rows for CHTR (Offset: 0)
# Fetched 1000 rows for PEP (Offset: 0)
# Fetched 1000 rows for LOGI (Offset: 0)
# Fetched 1000 rows for TSCO (Offset: 0)
# Fetched 1000 rows for GOLD (Offset: 0)
# Fetched 1000 rows for SPLK (Offset: 0)
# Fetched 1000 rows for ADSK (Offset: 0)
# Fetched 1000 rows for ADI (Offset: 0)
# Fetched 1000 rows for CERN (Offset: 0)
# Error for FWLT at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=FWLT&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Error for SHPG at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=SHPG&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for XEL (Offset: 0)
# Fetched 1000 rows for BATRA (Offset: 0)
# Fetched 1000 rows for EXPE (Offset: 0)
# Fetched 1000 rows for BATRK (Offset: 0)
# Fetched 1000 rows for DLTR (Offset: 0)
# Fetched 1000 rows for EXC (Offset: 0)
# Fetched 1000 rows for MU (Offset: 0)
# Fetched 1000 rows for INSM (Offset: 0)
# Fetched 1000 rows for HOLX (Offset: 0)
# Fetched 1000 rows for NTES (Offset: 0)
# Fetched 1000 rows for VRSN (Offset: 0)
# Fetched 1000 rows for ALNY (Offset: 0)
# Fetched 1000 rows for BMRN (Offset: 0)
# Fetched 1000 rows for SWKS (Offset: 0)
# Fetched 1000 rows for CMCSA (Offset: 0)
# Fetched 1000 rows for ADBE (Offset: 0)
# Fetched 1000 rows for MPWR (Offset: 0)
# Fetched 1000 rows for WBA (Offset: 0)
# Fetched 1000 rows for FAST (Offset: 0)
# Fetched 1000 rows for HON (Offset: 0)
# Fetched 1000 rows for CA (Offset: 0)
# Fetched 1000 rows for OKTA (Offset: 0)
# Fetched 1000 rows for URBN (Offset: 0)
# Fetched 1000 rows for LCID (Offset: 0)
# Fetched 194 rows for FB (Offset: 0)
# Fetched 1000 rows for GILD (Offset: 0)
# Fetched 1000 rows for PAYX (Offset: 0)
# Error for KRFT at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=KRFT&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for CTAS (Offset: 0)
# Fetched 1000 rows for AAL (Offset: 0)
# Fetched 1000 rows for MCHP (Offset: 0)
# Fetched 1000 rows for TMUS (Offset: 0)
# Fetched 1000 rows for FOSL (Offset: 0)
# Fetched 1000 rows for CDW (Offset: 0)
# Error for BMC at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=BMC&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for IDXX (Offset: 0)
# Fetched 1000 rows for ULTA (Offset: 0)
# Fetched 1000 rows for AMD (Offset: 0)
# Fetched 1000 rows for ISRG (Offset: 0)
# Fetched 1000 rows for AZN (Offset: 0)
# Error for WFM at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=WFM&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for MAR (Offset: 0)
# Fetched 1000 rows for CSGP (Offset: 0)
# Error for CTRX at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=CTRX&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for CSX (Offset: 0)
# Fetched 1000 rows for PLTR (Offset: 0)
# Fetched 1000 rows for ROST (Offset: 0)
# Fetched 1000 rows for DISH (Offset: 0)
# Fetched 1000 rows for LILAK (Offset: 0)
# Error for LMCA at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=LMCA&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for ENDP (Offset: 0)
# Fetched 1000 rows for INCY (Offset: 0)
# Fetched 1000 rows for TTWO (Offset: 0)
# Fetched 1000 rows for DOCU (Offset: 0)
# Fetched 1000 rows for FFIV (Offset: 0)
# Fetched 1000 rows for GOOG (Offset: 0)
# Fetched 1000 rows for NVDA (Offset: 0)
# Error for MYL at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=MYL&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for DDOG (Offset: 0)
# Fetched 1000 rows for COST (Offset: 0)
# Fetched 1000 rows for WDC (Offset: 0)
# Error for LILU at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=LILU&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 115 rows for PCLN (Offset: 0)
# Fetched 1000 rows for SGEN (Offset: 0)
# Fetched 1000 rows for VRSK (Offset: 0)
# Fetched 1000 rows for KHC (Offset: 0)
# Fetched 1000 rows for PYPL (Offset: 0)
# Fetched 1000 rows for PDD (Offset: 0)
# Fetched 867 rows for APP (Offset: 0)
# Fetched 1000 rows for DXCM (Offset: 0)
# Fetched 1000 rows for MRNA (Offset: 0)
# Fetched 1000 rows for ZM (Offset: 0)
# Fetched 1000 rows for FOX (Offset: 0)
# Error for LMCK at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=LMCK&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for INTC (Offset: 0)
# Fetched 1000 rows for CRWD (Offset: 0)
# Fetched 1000 rows for TXN (Offset: 0)
# Fetched 1000 rows for FTNT (Offset: 0)
# Fetched 1000 rows for WLTW (Offset: 0)
# Fetched 1000 rows for ASML (Offset: 0)
# Fetched 1000 rows for GOOGL (Offset: 0)
# Fetched 1000 rows for JBHT (Offset: 0)
# Fetched 1000 rows for CDNS (Offset: 0)
# Fetched 1000 rows for SBAC (Offset: 0)
# Fetched 1000 rows for LRCX (Offset: 0)
# Error for VIACOM at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=VIACOM&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for JD (Offset: 0)
# Fetched 1000 rows for SIRI (Offset: 0)
# Fetched 1000 rows for MELI (Offset: 0)
# Fetched 1000 rows for ROP (Offset: 0)
# Fetched 1000 rows for CEG (Offset: 0)
# Fetched 1000 rows for DASH (Offset: 0)
# Error for VMED at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=VMED&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for VOD (Offset: 0)
# Fetched 1000 rows for AMGN (Offset: 0)
# Fetched 1000 rows for STX (Offset: 0)
# Fetched 1000 rows for SNDK (Offset: 0)
# Fetched 1000 rows for STLD (Offset: 0)
# Fetched 1000 rows for EQIX (Offset: 0)
# Fetched 1000 rows for WYNN (Offset: 0)
# Fetched 1000 rows for QGEN (Offset: 0)
# Fetched 1000 rows for FSLR (Offset: 0)
# Fetched 1000 rows for MSFT (Offset: 0)
# Fetched 1000 rows for HAS (Offset: 0)
# Fetched 1000 rows for ANSS (Offset: 0)
# Fetched 1000 rows for AKAM (Offset: 0)
# Fetched 1000 rows for FLIR (Offset: 0)
# Fetched 814 rows for GEHC (Offset: 0)
# Fetched 1000 rows for TRI (Offset: 0)
# Error for WCRX at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=WCRX&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for BKNG (Offset: 0)
# Fetched 1000 rows for NUAN (Offset: 0)
# Fetched 1000 rows for BIDU (Offset: 0)
# Fetched 1000 rows for ALXN (Offset: 0)
# Fetched 1000 rows for ZS (Offset: 0)
# Fetched 1000 rows for DISCA (Offset: 0)
# Fetched 1000 rows for PRGO (Offset: 0)
# Fetched 1000 rows for AVGO (Offset: 0)
# Fetched 1000 rows for AMZN (Offset: 0)
# Error for PPDI at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=PPDI&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for ILMN (Offset: 0)
# Error for FMCN at offset 0: 406 Client Error: Not Acceptable for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=FMCN&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for WMT (Offset: 0)
# Fetched 1000 rows for SBUX (Offset: 0)
# Fetched 449 rows for LEAP (Offset: 0)
# Error for UAUA at offset 0: 422 Client Error: Unprocessable Entity for url: http://api.marketstack.com/v1/eod?access_key=208217244faa021e090f474a32663188&symbols=UAUA&date_from=2003-12-29&date_to=2026-04-06&limit=1000&offset=0
# Fetched 1000 rows for CTSH (Offset: 0)
# Fetched 1000 rows for SHOP (Offset: 0)
# Fetched 1000 rows for TRIP (Offset: 0)
# Fetched 1000 rows for EA (Offset: 0)
# Fetched 1000 rows for RYAAY (Offset: 0)
# Fetched 1000 rows for NTAP (Offset: 0)
# Fetched 1000 rows for LBTYK (Offset: 0)
# Fetched 1000 rows for LIN (Offset: 0)
# Fetched 1000 rows for HSIC (Offset: 0)
# Fetched 1000 rows for MAT (Offset: 0)
# Fetched 1000 rows for CPRT (Offset: 0)
# Fetched 1000 rows for MTCH (Offset: 0)
# Fetched 1000 rows for KDP (Offset: 0)
# Fetched 1000 rows for ALGN (Offset: 0)
# Fetched 1000 rows for NFLX (Offset: 0)
# Fetched 1000 rows for TEAM (Offset: 0)
# Fetched 1000 rows for QCOM (Offset: 0)
# Fetched 1000 rows for REGN (Offset: 0)
# Fetched 1000 rows for FOXA (Offset: 0)
#
# Successfully fetched 172601 total rows across all tickers.

# %%
display(df_nasdaq_eod.head())
# Out:
#             Date Ticker   Open   High    Low  Close      Volume
# 72355 2022-04-07    AAL  17.14  17.25  16.37  16.95  42203200.0
# 72354 2022-04-08    AAL  16.87  17.02  16.57  16.59  22568900.0
# 72353 2022-04-11    AAL  16.50  17.23  16.41  16.97  24843600.0
# 72352 2022-04-12    AAL  17.13  17.16  16.69  17.13  31429300.0
# 72351 2022-04-13    AAL  17.88  18.99  17.86  18.95  90049000.0

# %%
print(df_nasdaq_eod.groupby('Ticker').agg({'Date': ['min', 'max']}))
# Out:
#              Date
#               min        max
# Ticker
# AAL    2022-04-07 2026-04-02
# AAPL   2022-04-07 2026-04-02
# ABNB   2022-04-07 2026-04-02
# ADBE   2022-04-07 2026-04-02
# ADI    2022-04-07 2026-04-02
# ...           ...        ...
# WYNN   2022-04-07 2026-04-02
# XEL    2022-04-07 2026-04-02
# XRAY   2022-04-07 2026-04-02
# ZM     2022-04-07 2026-04-02
# ZS     2022-04-07 2026-04-02
#
# [177 rows x 2 columns]

# %%
df_nasdaq_eod.to_csv('df_nasdaq_eod.csv', index=False)
